# %% [markdown]
# # SET UP

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from os import listdir
from os.path import isfile, join
import random
import shutil
from matplotlib.image import imread
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger

from tensorflow.keras.utils import Sequence
import time
import seaborn as sns
import DCGAN1 as gan
# Out:
# C:\Users\15197\AppData\Roaming\Python\Python39\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
IMG_DIR = './PokemonData'
dirs = os.listdir(IMG_DIR)
print(dirs[:5])
# Out:
# ['Abra', 'Aerodactyl', 'Alakazam', 'Alolan Sandslash', 'Arbok']

# %% [markdown]
# # DATA EXTRACTOR

# %%
def files_info_extractor(path):
    dir_list = os.listdir(path)
    y = []
    X = []
    for i in range(len(dir_list)):
        files = os.listdir(os.path.join(path,dir_list[i]))
        for j in range(len(files)):
            X.append([files[j],dir_list[i]])
    return X

# %%
x = files_info_extractor(IMG_DIR)
X = pd.DataFrame(x,columns=["file","label"])
X
# Out:
#                                       file  label
# 0     0282b2f3a22745f1a436054ea15a0ae5.jpg   Abra
# 1     06b9eec4827d4d49b1b4c284308708df.jpg   Abra
# 2     10a9f06ec6524c66b779ea80354f8519.jpg   Abra
# 3     1788abb8b51f48509cfac8067bd99e14.jpg   Abra
# 4     28cfad92ad934d1f9b579cbff4b5d012.jpg   Abra
# ...                                    ...    ...
# 6832  dd387067380e4d1f8672c30d4b567fac.jpg  Zubat
# 6833  e1997a18e61641a4b0e701f6bc4c70f4.jpg  Zubat
# 6834  e6cba9a117d64d849fcc389e04e92e11.jpg  Zubat
# 6835  f8788465c10a4ab8bb0aeb992ec060ce.jpg  Zubat
# 6836  fccfe4de71a543349378b09d91d3f745.jpg  Zubat
#
# [6837 rows x 2 columns]

# %%
def create_train_val_test_folder():
    os.system("mkdir train")
    os.system("mkdir test")
    os.system("mkdir val")
def clean_images():
    os.system("rm -r train/* test/* val/*")
    os.system("find train/ -name '*.*' -type f -delete")
    os.system("find val/ -name '*.*' -type f -delete")
    os.system("find test/ -name '*.*' -type f -delete")
def data_extractor(class_pct,train_pct,val_pct,test_pct):
    
    sub_classes = random.sample(dirs,int(len(dirs)*class_pct))
    for cla in sub_classes:
        os.system('mkdir "train/'+cla+'"')
        os.system('mkdir "test/'+cla+'"')
        os.system('mkdir "val/'+cla+'"')
        os.system("find train/"+cla+" -name '*.*' -type f -delete")
        os.system("find val/"+cla+" -name '*.*' -type f -delete")
        os.system("find test/"+cla+" -name '*.*' -type f -delete")
        temp_files = os.listdir(os.path.join(IMG_DIR,cla))
        files = [f for f in temp_files if isfile(os.path.join(IMG_DIR, cla,f))]
        train_files = random.sample(files,int(len(files)*(train_pct+val_pct+test_pct)))
        val_files = random.sample(train_files,int(len(files)*(val_pct+test_pct)))
        test_files = random.sample(val_files,int(len(files)*test_pct))
        train_files = [x for x in train_files if x not in val_files]
        val_files = [x for x in val_files if x not in test_files]
        for file in train_files:
            shutil.copy(os.path.join(IMG_DIR,cla,file), os.path.join('train',cla,file))
        for file in val_files:
            shutil.copy(os.path.join(IMG_DIR,cla,file), os.path.join('val',cla,file))
        for file in test_files:
            shutil.copy(os.path.join(IMG_DIR,cla,file), os.path.join('test',cla,file))
def data_extractor_gan(classes, train_pct, val_pct,test_pct):

# %%
gan_test_class = ["Arbok","Bulbasaur","Caterpie","Charizard","Cloyster","Cubone","Dewgong","Ditto","Dodrio","Dragonite","Dratini","Ekans"]

# %%
create_train_val_test_folder()
#clean_images()
data_extractor(1,0.7,0.2,0.1)

# %% [markdown]
# # USE GAN MODEL TO GENERATE MORE IMAGES

# %%
plt.title('Count of images', size=16)
sns.countplot(X["label"])
plt.ylabel('Count', size=12)
plt.xlabel('class', size=12)
sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()
# Out:
# C:\Users\15197\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
class_names = X["label"].unique()
max_num = X["label"].value_counts()

# %%
os.system("mkdir savedData")
for cla in class_names:
    os.system("mkdir savedData/"+cla)

# %%
class_names
# Out:
# array(['Abra', 'Aerodactyl', 'Alakazam', 'Alolan Sandslash', 'Arbok',
#        'Arcanine', 'Articuno', 'Beedrill', 'Bellsprout', 'Blastoise',
#        'Bulbasaur', 'Butterfree', 'Caterpie', 'Chansey', 'Charizard',
#        'Charmander', 'Charmeleon', 'Clefable', 'Clefairy', 'Cloyster',
#        'Cubone', 'Dewgong', 'Diglett', 'Ditto', 'Dodrio', 'Doduo',
#        'Dragonair', 'Dragonite', 'Dratini', 'Drowzee', 'Dugtrio', 'Eevee',
#        'Ekans', 'Electabuzz', 'Electrode', 'Exeggcute', 'Exeggutor',
#        'Farfetchd', 'Fearow', 'Flareon', 'Gastly', 'Gengar', 'Geodude',
#        'Gloom', 'Golbat', 'Goldeen', 'Golduck', 'Golem', 'Graveler',
#        'Grimer', 'Growlithe', 'Gyarados', 'Haunter', 'Hitmonchan',
#        'Hitmonlee', 'Horsea', 'Hypno', 'Ivysaur', 'Jigglypuff', 'Jolteon',
#        'Jynx', 'Kabuto', 'Kabutops', 'Kadabra', 'Kakuna', 'Kangaskhan',
#        'Kingler', 'Koffing', 'Krabby', 'Lapras', 'Lickitung', 'Machamp',
#        'Machoke', 'Machop', 'Magikarp', 'Magmar', 'Magnemite', 'Magneton',
#        'Mankey', 'Marowak', 'Meowth', 'Metapod', 'Mew', 'Mewtwo',
#        'Moltres', 'MrMime', 'Muk', 'Nidoking', 'Nidoqueen', 'Nidorina',
#        'Nidorino', 'Ninetales', 'Oddish', 'Omanyte', 'Omastar', 'Onix',
#        'Paras', 'Parasect', 'Persian', 'Pidgeot', 'Pidgeotto', 'Pidgey',
#        'Pikachu', 'Pinsir', 'Poliwag', 'Poliwhirl', 'Poliwrath', 'Ponyta',
#        'Porygon', 'Primeape', 'Psyduck', 'Raichu', 'Rapidash', 'Raticate',
#        'Rattata', 'Rhydon', 'Rhyhorn', 'Sandshrew', 'Sandslash',
#        'Scyther', 'Seadra', 'Seaking', 'Seel', 'Shellder', 'Slowbro',
#        'Slowpoke', 'Snorlax', 'Spearow', 'Squirtle', 'Starmie', 'Staryu',
#        'Tangela', 'Tauros', 'Tentacool', 'Tentacruel', 'Vaporeon',
#        'Venomoth', 'Venonat', 'Venusaur', 'Victreebel', 'Vileplume',
#        'Voltorb', 'Vulpix', 'Wartortle', 'Weedle', 'Weepinbell',
#        'Weezing', 'Wigglytuff', 'Zapdos', 'Zubat'], dtype=object)

# %%
pokemon_class = ["Cloyster"]

# %%
import DCGAN as gan

for pokemon in pokemon_class:
    train_dataset = gan.create_dataset(os.path.join(IMG_DIR, pokemon) + "/*")
    save = str("./savedData/" + pokemon + "/")
    
    gan.train(train_dataset, epochs=4000, save_after=100, save_URL = save,num=36)
# Out:
# Lossy conversion from float32 to uint8. Range [0.084503173828125, 254.77975463867188]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.080078125, 254.74803161621094]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.081756591796875, 254.670654296875]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0805816650390625, 254.70956420898438]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0800018310546875, 254.97531127929688]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0800018310546875, 254.81719970703125]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0800018310546875, 254.724609375]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0800018310546875, 254.68881225585938]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.08203887939453125, 254.71218872070312]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0800018310546875, 254.73605346679688]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0815887451171875, 254.73275756835938]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.08060455322265625, 254.80177307128906]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0800018310546875, 254.54885864257812]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0800628662109375, 254.65341186523438]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0800018310546875, 254.94131469726562]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.08016204833984375, 254.72946166992188]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0800018310546875, 254.65557861328125]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0800018310546875, 254.74935913085938]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0802001953125, 254.81039428710938]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.08026123046875, 254.78631591796875]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0800018310546875, 254.75796508789062]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.08061981201171875, 254.67715454101562]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.080078125, 254.78817749023438]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0800628662109375, 254.7666473388672]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0810546875, 254.7171630859375]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.080810546875, 254.7347412109375]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.08002471923828125, 254.641845703125]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0800018310546875, 254.8685760498047]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.08428955078125, 254.72535705566406]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0800018310546875, 254.86318969726562]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0802459716796875, 254.87005615234375]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.08003997802734375, 254.8153533935547]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.08065032958984375, 254.74388122558594]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0860595703125, 254.67295837402344]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0810546875, 254.73162841796875]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0800018310546875, 254.89358520507812]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# it means that the Generator found a certain mode in the data space tha tis able to continuously fool the Discriminator into thinking he sis seeing real samples instead of fake ones. In other words, it means that the Discriminator is unable to successfullly distinguish real and fake samples coming from that same data mode.

# %% [markdown]
# # TAKE A LOOK AT THE DATASET

# %%
test_path = 'PokemonData/Abra/4e554e4a0f624656a7b1542b679b6157.jpg'
plt.imshow(imread(test_path))

# %% [markdown]
# # DATA AUGMATION USING ImageDataGenerator

# %%
from keras.preprocessing.image import ImageDataGenerator

baselineDataGen = ImageDataGenerator()
rotateDataGen = ImageDataGenerator(rotation_range=40)
rescaleDataGen = ImageDataGenerator(rescale = 1./255)
zcaDataGen = ImageDataGenerator(zca_whitening=True)
zoomDataGen = ImageDataGenerator(zoom_range=0.5)
allDataGen = ImageDataGenerator(rotation_range=20,
                               rescale = 1./255,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               shear_range=0.1,
                               zoom_range=0.1,
                               horizontal_flip=True,
                               vertical_flip = True,
                               fill_mode='nearest')

plt.imshow(baselineDataGen.random_transform(imread(test_path)))
plt.imshow(rotateDataGen.random_transform(imread(test_path)))
plt.imshow(rescaleDataGen.random_transform(imread(test_path)))
plt.imshow(zcaDataGen.random_transform(imread(test_path)))
plt.imshow(zoomDataGen.random_transform(imread(test_path)))
plt.imshow(allDataGen.random_transform(imread(test_path)))

# %%
image_shape = (256,256,3)


def generateDataFromDirectory(dg):
    train = dg.flow_from_directory('train/',target_size=image_shape[:2],
                                                color_mode='rgb',
                                                batch_size=15,
                                                class_mode='categorical')
    test = dg.flow_from_directory('test/',target_size=image_shape[:2],
                                                color_mode='rgb',
                                                batch_size=15,
                                                class_mode='categorical')
    val = dg.flow_from_directory('val/',target_size=image_shape[:2],
                                                color_mode='rgb',
                                                batch_size=15,
                                                class_mode='categorical')
    return train, test, val

# %% [markdown]
# <h2> create callback_list for building model </h2>

# %%
os.system("mkdir saved_models")
filepath = "saved_models/weight-model-improvement-{epoch:02d}-{val_accuracy:.2f}-"+time.strftime("%Y%m%d-%H%M%S")+".h5"
checkpoint = ModelCheckpoint(filepath, monitor="val_accuracy",verbose=1,save_best_only=True, model="max", save_weights_only=False)
earlystopping = EarlyStopping(monitor="val_loss",patience=15,verbose=1,restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.1, patience=10, verbose=0,
    mode='auto', min_delta=0.0001, cooldown=0, min_lr=0,
)
log_csv = CSVLogger("my_logs.csv",separator=',', append=False)
callback_list = [checkpoint,earlystopping,log_csv]
callback_list_with_reduction = [checkpoint,earlystopping,log_csv,reduce_lr]

# %% [markdown]
# <h2> define function to create baseline model which we use as a baseline to compare with other models </h2>

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dropout, Flatten, Dense, Activation, BatchNormalization, Lambda
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam


def build_baseline():
    model = Sequential()

    model.add(Conv2D(filters=64,kernel_size=(3,3),padding='same',input_shape=image_shape,activation='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(Conv2D(filters=128,kernel_size=(3,3),padding='same',input_shape=image_shape,activation='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(Dropout(rate=0.25))

    model.add(Flatten())

    model.add(Dense(256,activation='relu'))
    model.add(Dense(150,activation='softmax'))


    model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

    return model

# %% [markdown]
# <h2> define function to compare the accuracy of different generators </h2>

# %%
def compared_generators(gens,labels):
    historys = []
    for i in range(len(gens)):
        gen = gens[i]
        label = labels[i]
        train, test, val = generateDataFromDirectory(gen)
        model = build_baseline()
        history = model.fit(train, epochs=10, validation_data=val,callbacks=callback_list)
        historys.append(history)
        loss_history = pd.DataFrame(history.history)
        plt.plot(loss_history['val_accuracy'],label=label)
    plt.legend()
    plt.savefig("compared_generators_"+time.strftime("%Y%m%d-%H%M%S")+".png")

    plt.show()
    return historys

# %%
gens = [baselineDataGen, rescaleDataGen, rotateDataGen, zcaDataGen, allDataGen]
labels = ["baseline","rescale","rotate","zca","all"]
generators_history = compared_generators(gens,labels)

# %%
#all_loss_history = pd.DataFrame(all_history.history)
#all_loss_history[['accuracy','val_accuracy']].plot()
#all_loss_history[['loss','val_loss']].plot()

# %% [markdown]
# https://stackoverflow.com/questions/51748514/does-imagedatagenerator-add-more-images-to-my-dataset <br />
# Further, I think it's worth clarifying the meaning of "augmentation" in this context: basically we are augmenting the images when we use ImageDataGenerator and enabling its augmentation capabilities. But the word "augmentation" here does not mean, say, if we have 100 original training images we end up having 1000 images per epoch after augmentation (i.e. the number of training images does not increase per epoch). Instead, it means we use a different transformation of each image in each epoch; hence, if we train our model for, say, 5 epochs, we have used 5 different versions of each original image in training (or 100 * 5 = 500 different images in the whole training, instead of using just the 100 original images in the whole training). To put it differently, the total number of unique images increases in the whole training from start to finish, and not per epoch.

# %% [markdown]
# use image generator to preprocess the images can improve the fitting ability of the model, and we now will try to modify the model structure to improve the generalization ability, that is using dropout, batch normalization, and weight decay to improve the accuracy.

# %% [markdown]
# <h2> define function to create model and compare the accuracy of different combination of decay_rate, decay_step,and initial rate

# %%
def build_model_with_decay(initial_rate,decay_step, decay_rate):
    model = Sequential()

    model.add(Conv2D(filters=64,kernel_size=(3,3),padding='same',input_shape=image_shape,activation='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(Conv2D(filters=128,kernel_size=(3,3),padding='same',input_shape=image_shape,activation='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(Dropout(rate=0.25))

    model.add(Flatten())

    model.add(Dense(256,activation='relu'))
    model.add(Dense(7,activation='softmax'))
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_rate,
    decay_steps=decay_step,
    decay_rate=decay_rate,
    staircase=True)


    model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=lr_schedule), metrics=['accuracy'])

    return model

# %%
def compared_decay_rate():
    initials = [0.001,0.0001]
    steps = [10000,100000]
    rates = [0.96]
    historys =[]
    for initial in initials:
        for step in steps:
            for rate in rates:
                train, test, val = generateDataFromDirectory(allDataGen)
                model = build_model_with_decay(initial, step, rate)
                history = model.fit(train, epochs=10, validation_data=val,callbacks=callback_list)
                historys.append(history)
                loss_history = pd.DataFrame(history.history)
                plt.plot(loss_history['val_accuracy'],label="initial: "+str(initial)+ " steps: "+str(step)+ " rate: "+str(rate))
    plt.legend()
    plt.show()
    plt.savefig("compared_decay_rate_"+time.strftime("%Y%m%d-%H%M%S")+".png")
    return historys

# %%
compared_decay_rate()
# Out:
# Found 129 images belonging to 7 classes.
# Found 29 images belonging to 7 classes.
# Found 33 images belonging to 7 classes.
# Epoch 1/10
# 9/9 [==============================] - ETA: 0s - loss: 18.9751 - accuracy: 0.2248
# Epoch 00001: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 31s 3s/step - loss: 18.9751 - accuracy: 0.2248 - val_loss: 1.9056 - val_accuracy: 0.1212
# Epoch 2/10
# 9/9 [==============================] - ETA: 0s - loss: 1.7988 - accuracy: 0.1318
# Epoch 00002: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 27s 3s/step - loss: 1.7988 - accuracy: 0.1318 - val_loss: 1.8791 - val_accuracy: 0.1818
# Epoch 3/10
# 9/9 [==============================] - ETA: 0s - loss: 1.6746 - accuracy: 0.2868
# Epoch 00003: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 26s 3s/step - loss: 1.6746 - accuracy: 0.2868 - val_loss: 1.9123 - val_accuracy: 0.2727
# Epoch 4/10
# 9/9 [==============================] - ETA: 0s - loss: 1.5389 - accuracy: 0.4496
# Epoch 00004: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 26s 3s/step - loss: 1.5389 - accuracy: 0.4496 - val_loss: 2.0278 - val_accuracy: 0.3030
# Epoch 5/10
# 9/9 [==============================] - ETA: 0s - loss: 1.5099 - accuracy: 0.4574
# Epoch 00005: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 27s 3s/step - loss: 1.5099 - accuracy: 0.4574 - val_loss: 1.6323 - val_accuracy: 0.4242
# Epoch 6/10
# 9/9 [==============================] - ETA: 0s - loss: 1.4858 - accuracy: 0.4341
# Epoch 00006: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 27s 3s/step - loss: 1.4858 - accuracy: 0.4341 - val_loss: 1.5816 - val_accuracy: 0.3030
# Epoch 7/10
# 9/9 [==============================] - ETA: 0s - loss: 1.2929 - accuracy: 0.5271
# Epoch 00007: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 27s 3s/step - loss: 1.2929 - accuracy: 0.5271 - val_loss: 1.4837 - val_accuracy: 0.4242
# Epoch 8/10
# 9/9 [==============================] - ETA: 0s - loss: 0.9450 - accuracy: 0.6667
# Epoch 00008: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 27s 3s/step - loss: 0.9450 - accuracy: 0.6667 - val_loss: 1.0926 - val_accuracy: 0.6061
# Epoch 9/10
# 9/9 [==============================] - ETA: 0s - loss: 0.9554 - accuracy: 0.6977
# Epoch 00009: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 26s 3s/step - loss: 0.9554 - accuracy: 0.6977 - val_loss: 0.9661 - val_accuracy: 0.7273
# Epoch 10/10
# 9/9 [==============================] - ETA: 0s - loss: 0.8502 - accuracy: 0.6744
# Epoch 00010: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 25s 3s/step - loss: 0.8502 - accuracy: 0.6744 - val_loss: 0.8726 - val_accuracy: 0.6364
# Found 129 images belonging to 7 classes.
# Found 29 images belonging to 7 classes.
# Found 33 images belonging to 7 classes.
# Epoch 1/10
# 9/9 [==============================] - ETA: 0s - loss: 17.3929 - accuracy: 0.1318
# Epoch 00001: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 26s 3s/step - loss: 17.3929 - accuracy: 0.1318 - val_loss: 1.9734 - val_accuracy: 0.2424
# Epoch 2/10
# 9/9 [==============================] - ETA: 0s - loss: 1.7621 - accuracy: 0.2791
# Epoch 00002: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 22s 2s/step - loss: 1.7621 - accuracy: 0.2791 - val_loss: 1.6297 - val_accuracy: 0.4242
# Epoch 3/10
# 9/9 [==============================] - ETA: 0s - loss: 1.4717 - accuracy: 0.4109
# Epoch 00003: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 22s 2s/step - loss: 1.4717 - accuracy: 0.4109 - val_loss: 1.2931 - val_accuracy: 0.5455
# Epoch 4/10
# 9/9 [==============================] - ETA: 0s - loss: 1.1384 - accuracy: 0.5814
# Epoch 00004: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 23s 2s/step - loss: 1.1384 - accuracy: 0.5814 - val_loss: 1.2826 - val_accuracy: 0.5152
# Epoch 5/10
# 9/9 [==============================] - ETA: 0s - loss: 1.0045 - accuracy: 0.5581
# Epoch 00005: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 23s 3s/step - loss: 1.0045 - accuracy: 0.5581 - val_loss: 0.9363 - val_accuracy: 0.6364
# Epoch 6/10
# 9/9 [==============================] - ETA: 0s - loss: 0.6713 - accuracy: 0.7287
# Epoch 00006: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 22s 2s/step - loss: 0.6713 - accuracy: 0.7287 - val_loss: 0.7688 - val_accuracy: 0.7273
# Epoch 7/10
# 9/9 [==============================] - ETA: 0s - loss: 0.6236 - accuracy: 0.7442
# Epoch 00007: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 21s 2s/step - loss: 0.6236 - accuracy: 0.7442 - val_loss: 1.2554 - val_accuracy: 0.5455
# Epoch 8/10
# 9/9 [==============================] - ETA: 0s - loss: 0.5686 - accuracy: 0.7984
# Epoch 00008: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 20s 2s/step - loss: 0.5686 - accuracy: 0.7984 - val_loss: 0.8939 - val_accuracy: 0.6970
# Epoch 9/10
# 9/9 [==============================] - ETA: 0s - loss: 0.3677 - accuracy: 0.8450
# Epoch 00009: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 22s 2s/step - loss: 0.3677 - accuracy: 0.8450 - val_loss: 0.7706 - val_accuracy: 0.6364
# Epoch 10/10
# 9/9 [==============================] - ETA: 0s - loss: 0.3966 - accuracy: 0.8450
# Epoch 00010: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 20s 2s/step - loss: 0.3966 - accuracy: 0.8450 - val_loss: 0.7878 - val_accuracy: 0.6667
# Found 129 images belonging to 7 classes.
# Found 29 images belonging to 7 classes.
# Found 33 images belonging to 7 classes.
# Epoch 1/10
# 9/9 [==============================] - ETA: 0s - loss: 3.8360 - accuracy: 0.1395
# Epoch 00001: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 27s 3s/step - loss: 3.8360 - accuracy: 0.1395 - val_loss: 2.7107 - val_accuracy: 0.2424
# Epoch 2/10
# 9/9 [==============================] - ETA: 0s - loss: 2.0379 - accuracy: 0.3566
# Epoch 00002: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 23s 2s/step - loss: 2.0379 - accuracy: 0.3566 - val_loss: 1.6203 - val_accuracy: 0.3636
# Epoch 3/10
# 9/9 [==============================] - ETA: 0s - loss: 1.4689 - accuracy: 0.4651
# Epoch 00003: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 23s 2s/step - loss: 1.4689 - accuracy: 0.4651 - val_loss: 1.2606 - val_accuracy: 0.5758
# Epoch 4/10
# 9/9 [==============================] - ETA: 0s - loss: 1.1571 - accuracy: 0.5504
# Epoch 00004: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 22s 2s/step - loss: 1.1571 - accuracy: 0.5504 - val_loss: 1.1450 - val_accuracy: 0.5758
# Epoch 5/10
# 9/9 [==============================] - ETA: 0s - loss: 0.9912 - accuracy: 0.6124
# Epoch 00005: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 23s 2s/step - loss: 0.9912 - accuracy: 0.6124 - val_loss: 0.9133 - val_accuracy: 0.7273
# Epoch 6/10
# 9/9 [==============================] - ETA: 0s - loss: 0.8068 - accuracy: 0.7364
# Epoch 00006: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 22s 2s/step - loss: 0.8068 - accuracy: 0.7364 - val_loss: 0.8242 - val_accuracy: 0.7273
# Epoch 7/10
# 9/9 [==============================] - ETA: 0s - loss: 0.7510 - accuracy: 0.7287
# Epoch 00007: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 23s 3s/step - loss: 0.7510 - accuracy: 0.7287 - val_loss: 0.7838 - val_accuracy: 0.7273
# Epoch 8/10
# 9/9 [==============================] - ETA: 0s - loss: 0.6194 - accuracy: 0.8527
# Epoch 00008: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 22s 2s/step - loss: 0.6194 - accuracy: 0.8527 - val_loss: 0.6732 - val_accuracy: 0.7273
# Epoch 9/10
# 9/9 [==============================] - ETA: 0s - loss: 0.5492 - accuracy: 0.8140
# Epoch 00009: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 22s 2s/step - loss: 0.5492 - accuracy: 0.8140 - val_loss: 0.7657 - val_accuracy: 0.6970
# Epoch 10/10
# 9/9 [==============================] - ETA: 0s - loss: 0.4703 - accuracy: 0.8605
# Epoch 00010: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 22s 2s/step - loss: 0.4703 - accuracy: 0.8605 - val_loss: 0.6353 - val_accuracy: 0.7576
# Found 129 images belonging to 7 classes.
# Found 29 images belonging to 7 classes.
# Found 33 images belonging to 7 classes.
# Epoch 1/10
# 9/9 [==============================] - ETA: 0s - loss: 3.2514 - accuracy: 0.1550
# Epoch 00001: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 26s 3s/step - loss: 3.2514 - accuracy: 0.1550 - val_loss: 2.4390 - val_accuracy: 0.1515
# Epoch 2/10
# 9/9 [==============================] - ETA: 0s - loss: 1.8948 - accuracy: 0.2403
# Epoch 00002: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 25s 3s/step - loss: 1.8948 - accuracy: 0.2403 - val_loss: 1.7762 - val_accuracy: 0.3939
# Epoch 3/10
# 9/9 [==============================] - ETA: 0s - loss: 1.7190 - accuracy: 0.4109
# Epoch 00003: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 23s 2s/step - loss: 1.7190 - accuracy: 0.4109 - val_loss: 1.5935 - val_accuracy: 0.4848
# Epoch 4/10
# 9/9 [==============================] - ETA: 0s - loss: 1.4100 - accuracy: 0.5194
# Epoch 00004: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 21s 2s/step - loss: 1.4100 - accuracy: 0.5194 - val_loss: 1.3330 - val_accuracy: 0.4848
# Epoch 5/10
# 9/9 [==============================] - ETA: 0s - loss: 1.2099 - accuracy: 0.5814
# Epoch 00005: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 22s 2s/step - loss: 1.2099 - accuracy: 0.5814 - val_loss: 1.1570 - val_accuracy: 0.5758
# Epoch 6/10
# 9/9 [==============================] - ETA: 0s - loss: 1.1209 - accuracy: 0.5969
# Epoch 00006: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 22s 2s/step - loss: 1.1209 - accuracy: 0.5969 - val_loss: 1.1045 - val_accuracy: 0.5455
# Epoch 7/10
# 9/9 [==============================] - ETA: 0s - loss: 0.9511 - accuracy: 0.6977
# Epoch 00007: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 21s 2s/step - loss: 0.9511 - accuracy: 0.6977 - val_loss: 0.9688 - val_accuracy: 0.6061
# Epoch 8/10
# 9/9 [==============================] - ETA: 0s - loss: 0.8365 - accuracy: 0.6977
# Epoch 00008: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 22s 2s/step - loss: 0.8365 - accuracy: 0.6977 - val_loss: 0.8774 - val_accuracy: 0.6364
# Epoch 9/10
# 9/9 [==============================] - ETA: 0s - loss: 0.7660 - accuracy: 0.6977
# Epoch 00009: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 22s 2s/step - loss: 0.7660 - accuracy: 0.6977 - val_loss: 0.8143 - val_accuracy: 0.7273
# Epoch 10/10
# 9/9 [==============================] - ETA: 0s - loss: 0.7252 - accuracy: 0.8062
# Epoch 00010: val_accuracy did not improve from 0.78788
# 9/9 [==============================] - 21s 2s/step - loss: 0.7252 - accuracy: 0.8062 - val_loss: 0.7786 - val_accuracy: 0.7273
# [<keras.callbacks.History at 0x7f24a077d430>,
#  <keras.callbacks.History at 0x7f24a061ddc0>,
#  <keras.callbacks.History at 0x7f24a04b9880>,
#  <keras.callbacks.History at 0x7f24a033a7f0>]

# %% [markdown]
# <h2> define function to compare accuracy between model using decay and reduction </h2>

# %%
def compared_reduction_decay():
    train, test, val = generateDataFromDirectory(allDataGen)
    reduction_model = build_baseline()
    decay_model = build_model_with_decay(0.0001,10000,0.96)
    #combined_model = build_model_with_decay(0.001,10000,0.96)
    reduction_history = reduction_model.fit(train, epochs=20,validation_data=val,callbacks=callback_list_with_reduction)
    decay_history = decay_model.fit(train, epochs=10,validation_data=val,callbacks=callback_list)
    #combined_history = combined_model.fit(train, epochs=10,validation_data=val,callbacks=callback_list_with_reduction)
                
    historys = [reduction_history, decay_history]
    reduction_loss_history = pd.DataFrame(reduction_history.history)
    decay_loss_history = pd.DataFrame(decay_history.history)
    #combined_loss_history = pd.DataFrame(combined_history.history)
    plt.plot(reduction_loss_history['val_accuracy'],label="reduction")
    plt.plot(decay_loss_history['val_accuracy'],label="decay")
    #plt.plot(combined_loss_history['val_accuracy'],label="combined")
    plt.legend()
    plt.savefig("compared_reduction_rate_"+time.strftime("%Y%m%d-%H%M%S")+".png")
    plt.show()
    return historys

# %%
compared_reduction_decay()
# Out:
# Found 132 images belonging to 7 classes.
# Found 31 images belonging to 7 classes.
# Found 34 images belonging to 7 classes.
# Epoch 1/20
# 9/9 [==============================] - ETA: 0s - loss: 15.7183 - accuracy: 0.1212
# Epoch 00001: val_accuracy did not improve from 0.70588
# 9/9 [==============================] - 27s 3s/step - loss: 15.7183 - accuracy: 0.1212 - val_loss: 1.8250 - val_accuracy: 0.2941 - lr: 0.0010
# Epoch 2/20
# 9/9 [==============================] - ETA: 0s - loss: 1.6421 - accuracy: 0.3939
# Epoch 00002: val_accuracy did not improve from 0.70588
# 9/9 [==============================] - 24s 3s/step - loss: 1.6421 - accuracy: 0.3939 - val_loss: 1.5315 - val_accuracy: 0.3824 - lr: 0.0010
# Epoch 3/20
# 9/9 [==============================] - ETA: 0s - loss: 1.2716 - accuracy: 0.5000
# Epoch 00003: val_accuracy did not improve from 0.70588
# 9/9 [==============================] - 21s 2s/step - loss: 1.2716 - accuracy: 0.5000 - val_loss: 1.5634 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 4/20
# 9/9 [==============================] - ETA: 0s - loss: 1.0913 - accuracy: 0.5833
# Epoch 00004: val_accuracy did not improve from 0.70588
# 9/9 [==============================] - 21s 2s/step - loss: 1.0913 - accuracy: 0.5833 - val_loss: 2.0521 - val_accuracy: 0.4706 - lr: 0.0010
# Epoch 5/20
# 9/9 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.5758
# Epoch 00005: val_accuracy did not improve from 0.70588
# 9/9 [==============================] - 22s 2s/step - loss: 1.0952 - accuracy: 0.5758 - val_loss: 1.4650 - val_accuracy: 0.7059 - lr: 0.0010
# Epoch 6/20
# 9/9 [==============================] - ETA: 0s - loss: 0.8883 - accuracy: 0.6894
# Epoch 00006: val_accuracy did not improve from 0.70588
# 9/9 [==============================] - 25s 3s/step - loss: 0.8883 - accuracy: 0.6894 - val_loss: 1.3331 - val_accuracy: 0.6471 - lr: 0.0010
# Epoch 7/20
# 9/9 [==============================] - ETA: 0s - loss: 0.7332 - accuracy: 0.7273
# Epoch 00007: val_accuracy did not improve from 0.70588
# 9/9 [==============================] - 22s 2s/step - loss: 0.7332 - accuracy: 0.7273 - val_loss: 1.4010 - val_accuracy: 0.7059 - lr: 0.0010
# Epoch 8/20
# 9/9 [==============================] - ETA: 0s - loss: 0.5692 - accuracy: 0.7727
# Epoch 00008: val_accuracy did not improve from 0.70588
# 9/9 [==============================] - 23s 2s/step - loss: 0.5692 - accuracy: 0.7727 - val_loss: 1.0858 - val_accuracy: 0.6471 - lr: 0.0010
# Epoch 9/20
# 9/9 [==============================] - ETA: 0s - loss: 0.4101 - accuracy: 0.8409
# Epoch 00009: val_accuracy did not improve from 0.70588
# 9/9 [==============================] - 21s 2s/step - loss: 0.4101 - accuracy: 0.8409 - val_loss: 1.3218 - val_accuracy: 0.6765 - lr: 0.0010
# Epoch 10/20
# 9/9 [==============================] - ETA: 0s - loss: 0.5098 - accuracy: 0.8182
# Epoch 00010: val_accuracy did not improve from 0.70588
# 9/9 [==============================] - 21s 2s/step - loss: 0.5098 - accuracy: 0.8182 - val_loss: 1.2062 - val_accuracy: 0.6765 - lr: 0.0010
# Epoch 11/20
# 9/9 [==============================] - ETA: 0s - loss: 0.4449 - accuracy: 0.8106
# Epoch 00011: val_accuracy did not improve from 0.70588
# 9/9 [==============================] - 23s 3s/step - loss: 0.4449 - accuracy: 0.8106 - val_loss: 1.0046 - val_accuracy: 0.7059 - lr: 0.0010
# Epoch 12/20
# 9/9 [==============================] - ETA: 0s - loss: 0.3917 - accuracy: 0.8561
# Epoch 00012: val_accuracy did not improve from 0.70588
# 9/9 [==============================] - 21s 2s/step - loss: 0.3917 - accuracy: 0.8561 - val_loss: 1.0420 - val_accuracy: 0.6765 - lr: 0.0010
# Epoch 13/20
# 9/9 [==============================] - ETA: 0s - loss: 0.5424 - accuracy: 0.7879
# Epoch 00013: val_accuracy improved from 0.70588 to 0.76471, saving model to saved_models/weight-model-improvement-13-0.76-20211118-232522.h5
# 9/9 [==============================] - 33s 4s/step - loss: 0.5424 - accuracy: 0.7879 - val_loss: 1.0211 - val_accuracy: 0.7647 - lr: 0.0010
# Epoch 14/20
# 9/9 [==============================] - ETA: 0s - loss: 0.3385 - accuracy: 0.8636
# Epoch 00014: val_accuracy did not improve from 0.76471
# 9/9 [==============================] - 21s 2s/step - loss: 0.3385 - accuracy: 0.8636 - val_loss: 1.9989 - val_accuracy: 0.6765 - lr: 0.0010
# Epoch 15/20
# 9/9 [==============================] - ETA: 0s - loss: 0.4298 - accuracy: 0.8333
# Epoch 00015: val_accuracy did not improve from 0.76471
# 9/9 [==============================] - 21s 2s/step - loss: 0.4298 - accuracy: 0.8333 - val_loss: 1.0872 - val_accuracy: 0.7647 - lr: 1.0000e-04
# Epoch 16/20
# 9/9 [==============================] - ETA: 0s - loss: 0.2671 - accuracy: 0.8712
# Epoch 00016: val_accuracy did not improve from 0.76471
# 9/9 [==============================] - 23s 2s/step - loss: 0.2671 - accuracy: 0.8712 - val_loss: 1.1194 - val_accuracy: 0.7059 - lr: 1.0000e-04
# Epoch 17/20
# 9/9 [==============================] - ETA: 0s - loss: 0.2364 - accuracy: 0.9318
# Epoch 00017: val_accuracy did not improve from 0.76471
# 9/9 [==============================] - 20s 2s/step - loss: 0.2364 - accuracy: 0.9318 - val_loss: 1.1429 - val_accuracy: 0.7353 - lr: 1.0000e-04
# Epoch 18/20
# 9/9 [==============================] - ETA: 0s - loss: 0.2512 - accuracy: 0.9091
# Epoch 00018: val_accuracy did not improve from 0.76471
# 9/9 [==============================] - 22s 2s/step - loss: 0.2512 - accuracy: 0.9091 - val_loss: 1.3346 - val_accuracy: 0.6765 - lr: 1.0000e-05
# Epoch 19/20
# 9/9 [==============================] - ETA: 0s - loss: 0.2482 - accuracy: 0.9015
# Epoch 00019: val_accuracy did not improve from 0.76471
# 9/9 [==============================] - 20s 2s/step - loss: 0.2482 - accuracy: 0.9015 - val_loss: 1.1034 - val_accuracy: 0.7647 - lr: 1.0000e-05
# Epoch 20/20
# 9/9 [==============================] - ETA: 0s - loss: 0.2546 - accuracy: 0.9318
# Epoch 00020: val_accuracy improved from 0.76471 to 0.79412, saving model to saved_models/weight-model-improvement-20-0.79-20211118-232522.h5
# 9/9 [==============================] - 33s 4s/step - loss: 0.2546 - accuracy: 0.9318 - val_loss: 0.9988 - val_accuracy: 0.7941 - lr: 1.0000e-05
# Epoch 1/10
# 9/9 [==============================] - ETA: 0s - loss: 4.4272 - accuracy: 0.1515
# Epoch 00001: val_accuracy did not improve from 0.79412
# 9/9 [==============================] - 27s 3s/step - loss: 4.4272 - accuracy: 0.1515 - val_loss: 2.9269 - val_accuracy: 0.2059
# Epoch 2/10
# 9/9 [==============================] - ETA: 0s - loss: 2.4168 - accuracy: 0.2197
# Epoch 00002: val_accuracy did not improve from 0.79412
# 9/9 [==============================] - 26s 3s/step - loss: 2.4168 - accuracy: 0.2197 - val_loss: 1.9658 - val_accuracy: 0.2941
# Epoch 3/10
# 9/9 [==============================] - ETA: 0s - loss: 1.7447 - accuracy: 0.3485
# Epoch 00003: val_accuracy did not improve from 0.79412
# 9/9 [==============================] - 28s 3s/step - loss: 1.7447 - accuracy: 0.3485 - val_loss: 1.6259 - val_accuracy: 0.4706
# Epoch 4/10
# 9/9 [==============================] - ETA: 0s - loss: 1.4524 - accuracy: 0.4697
# Epoch 00004: val_accuracy did not improve from 0.79412
# 9/9 [==============================] - 25s 3s/step - loss: 1.4524 - accuracy: 0.4697 - val_loss: 1.4754 - val_accuracy: 0.4412
# Epoch 5/10
# 9/9 [==============================] - ETA: 0s - loss: 1.2293 - accuracy: 0.5833
# Epoch 00005: val_accuracy did not improve from 0.79412
# 9/9 [==============================] - 22s 2s/step - loss: 1.2293 - accuracy: 0.5833 - val_loss: 1.4361 - val_accuracy: 0.5588
# Epoch 6/10
# 9/9 [==============================] - ETA: 0s - loss: 1.1107 - accuracy: 0.6061
# Epoch 00006: val_accuracy did not improve from 0.79412
# 9/9 [==============================] - 22s 2s/step - loss: 1.1107 - accuracy: 0.6061 - val_loss: 1.2771 - val_accuracy: 0.5882
# Epoch 7/10
# 9/9 [==============================] - ETA: 0s - loss: 1.0036 - accuracy: 0.6515
# Epoch 00007: val_accuracy did not improve from 0.79412
# 9/9 [==============================] - 20s 2s/step - loss: 1.0036 - accuracy: 0.6515 - val_loss: 1.3638 - val_accuracy: 0.5000
# Epoch 8/10
# 9/9 [==============================] - ETA: 0s - loss: 0.9120 - accuracy: 0.6742
# Epoch 00008: val_accuracy did not improve from 0.79412
# 9/9 [==============================] - 22s 2s/step - loss: 0.9120 - accuracy: 0.6742 - val_loss: 1.0710 - val_accuracy: 0.7647
# Epoch 9/10
# 9/9 [==============================] - ETA: 0s - loss: 0.7546 - accuracy: 0.7576
# Epoch 00009: val_accuracy did not improve from 0.79412
# 9/9 [==============================] - 21s 2s/step - loss: 0.7546 - accuracy: 0.7576 - val_loss: 1.1549 - val_accuracy: 0.6176
# Epoch 10/10
# 9/9 [==============================] - ETA: 0s - loss: 0.7086 - accuracy: 0.7576
# Epoch 00010: val_accuracy did not improve from 0.79412
# 9/9 [==============================] - 20s 2s/step - loss: 0.7086 - accuracy: 0.7576 - val_loss: 1.2580 - val_accuracy: 0.6176
# [<keras.callbacks.History at 0x7f3cf068f580>,
#  <keras.callbacks.History at 0x7f3d10052d60>]

# %% [markdown]
# # building the final model and evaluate it

# %%
os.system("mkdir saved_models")
filepath = "saved_models/weight-model-improvement-{epoch:02d}-{val_accuracy:.2f}-"+time.strftime("%Y%m%d-%H%M%S")+".h5"
checkpoint = ModelCheckpoint(filepath, monitor="val_accuracy",verbose=1,save_best_only=True, model="max", save_weights_only=False)
earlystopping = EarlyStopping(monitor="val_loss",patience=15,verbose=1,restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.1, patience=10, verbose=0,
    mode='auto', min_delta=0.0001, cooldown=0, min_lr=0,
)
log_csv = CSVLogger("my_logs.csv",separator=',', append=False)
callback_list = [checkpoint,earlystopping,log_csv]
callback_list_with_reduction = [checkpoint,earlystopping,log_csv,reduce_lr]

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dropout, Flatten, Dense, Activation, BatchNormalization, Lambda
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam


def build_final_model():
    model = Sequential()

    model.add(Conv2D(filters=64,kernel_size=(3,3),padding='same',input_shape=image_shape,activation='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(Conv2D(filters=128,kernel_size=(3,3),padding='same',input_shape=image_shape,activation='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(Dropout(rate=0.25))
    model.add(BatchNormalization())
    model.add(Conv2D(filters=128,kernel_size=(3,3),padding='same',input_shape=image_shape,activation='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(Conv2D(filters=128,kernel_size=(3,3),padding='same',input_shape=image_shape,activation='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(Dropout(rate=0.25))
    model.add(BatchNormalization())


    model.add(Flatten())

    model.add(Dense(1024,activation='relu'))

    model.add(Dropout(rate=0.25))

    model.add(Dense(512,activation='relu'))

    model.add(Dense(150,activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

    return model

# %%
train, test, val = generateDataFromDirectory(allDataGen)
reduction_model = build_final_model()
reduction_history = reduction_model.fit(train, epochs=100,validation_data=val,callbacks=callback_list_with_reduction)
reduction_loss_history = pd.DataFrame(reduction_history.history)

plt.legend()
plt.savefig("final_model"+time.strftime("%Y%m%d-%H%M%S")+".png")
plt.show()
# Out:
# Found 4704 images belonging to 150 classes.
# Found 616 images belonging to 150 classes.
# Found 1366 images belonging to 150 classes.
# Epoch 1/100
# 314/314 [==============================] - ETA: 0s - loss: 5.1387 - accuracy: 0.0151
# Epoch 00001: val_accuracy improved from -inf to 0.01171, saving model to saved_models\weight-model-improvement-01-0.01-20211124-140751.h5
# 314/314 [==============================] - 100s 314ms/step - loss: 5.1387 - accuracy: 0.0151 - val_loss: 6.9178 - val_accuracy: 0.0117 - lr: 0.0010
# Epoch 2/100
# 314/314 [==============================] - ETA: 0s - loss: 4.5109 - accuracy: 0.0317
# Epoch 00002: val_accuracy improved from 0.01171 to 0.02416, saving model to saved_models\weight-model-improvement-02-0.02-20211124-140751.h5
# 314/314 [==============================] - 80s 255ms/step - loss: 4.5109 - accuracy: 0.0317 - val_loss: 4.9514 - val_accuracy: 0.0242 - lr: 0.0010
# Epoch 3/100
# 314/314 [==============================] - ETA: 0s - loss: 4.1042 - accuracy: 0.0599
# Epoch 00003: val_accuracy improved from 0.02416 to 0.03221, saving model to saved_models\weight-model-improvement-03-0.03-20211124-140751.h5
# 314/314 [==============================] - 80s 255ms/step - loss: 4.1042 - accuracy: 0.0599 - val_loss: 5.3536 - val_accuracy: 0.0322 - lr: 0.0010
# Epoch 4/100
# 314/314 [==============================] - ETA: 0s - loss: 3.8634 - accuracy: 0.0778
# Epoch 00004: val_accuracy improved from 0.03221 to 0.09004, saving model to saved_models\weight-model-improvement-04-0.09-20211124-140751.h5
# 314/314 [==============================] - 80s 255ms/step - loss: 3.8634 - accuracy: 0.0778 - val_loss: 3.7663 - val_accuracy: 0.0900 - lr: 0.0010
# Epoch 5/100
# 314/314 [==============================] - ETA: 0s - loss: 3.6732 - accuracy: 0.09 - ETA: 0s - loss: 3.6738 - accuracy: 0.0986
# Epoch 00005: val_accuracy improved from 0.09004 to 0.11054, saving model to saved_models\weight-model-improvement-05-0.11-20211124-140751.h5
# 314/314 [==============================] - 80s 255ms/step - loss: 3.6738 - accuracy: 0.0986 - val_loss: 3.7897 - val_accuracy: 0.1105 - lr: 0.0010
# Epoch 6/100
# 314/314 [==============================] - ETA: 0s - loss: 3.5230 - accuracy: 0.1165
# Epoch 00006: val_accuracy improved from 0.11054 to 0.11420, saving model to saved_models\weight-model-improvement-06-0.11-20211124-140751.h5
# 314/314 [==============================] - 80s 256ms/step - loss: 3.5230 - accuracy: 0.1165 - val_loss: 3.7628 - val_accuracy: 0.1142 - lr: 0.0010
# Epoch 7/100
# 314/314 [==============================] - ETA: 0s - loss: 3.3711 - accuracy: 0.1331
# Epoch 00007: val_accuracy improved from 0.11420 to 0.14129, saving model to saved_models\weight-model-improvement-07-0.14-20211124-140751.h5
# 314/314 [==============================] - 81s 256ms/step - loss: 3.3711 - accuracy: 0.1331 - val_loss: 3.5827 - val_accuracy: 0.1413 - lr: 0.0010
# Epoch 8/100
# 314/314 [==============================] - ETA: 0s - loss: 3.2577 - accuracy: 0.1511
# Epoch 00008: val_accuracy improved from 0.14129 to 0.14861, saving model to saved_models\weight-model-improvement-08-0.15-20211124-140751.h5
# 314/314 [==============================] - 80s 255ms/step - loss: 3.2577 - accuracy: 0.1511 - val_loss: 3.5870 - val_accuracy: 0.1486 - lr: 0.0010
# Epoch 9/100
# 314/314 [==============================] - ETA: 0s - loss: 3.2022 - accuracy: 0.1707
# Epoch 00009: val_accuracy did not improve from 0.14861
# 314/314 [==============================] - 78s 248ms/step - loss: 3.2022 - accuracy: 0.1707 - val_loss: 3.6734 - val_accuracy: 0.1296 - lr: 0.0010
# Epoch 10/100
# 314/314 [==============================] - ETA: 0s - loss: 3.1383 - accuracy: 0.1745
# Epoch 00010: val_accuracy improved from 0.14861 to 0.14934, saving model to saved_models\weight-model-improvement-10-0.15-20211124-140751.h5
# 314/314 [==============================] - 80s 254ms/step - loss: 3.1383 - accuracy: 0.1745 - val_loss: 3.5480 - val_accuracy: 0.1493 - lr: 0.0010
# Epoch 11/100
# 314/314 [==============================] - ETA: 0s - loss: 3.0719 - accuracy: 0.1884
# Epoch 00011: val_accuracy improved from 0.14934 to 0.19985, saving model to saved_models\weight-model-improvement-11-0.20-20211124-140751.h5
# 314/314 [==============================] - 80s 255ms/step - loss: 3.0719 - accuracy: 0.1884 - val_loss: 3.1374 - val_accuracy: 0.1999 - lr: 0.0010
# Epoch 12/100
# 314/314 [==============================] - ETA: 0s - loss: 2.9832 - accuracy: 0.2066
# Epoch 00012: val_accuracy did not improve from 0.19985
# 314/314 [==============================] - 78s 247ms/step - loss: 2.9832 - accuracy: 0.2066 - val_loss: 3.2936 - val_accuracy: 0.1918 - lr: 0.0010
# Epoch 13/100
# 314/314 [==============================] - ETA: 0s - loss: 2.9502 - accuracy: 0.2088
# Epoch 00013: val_accuracy improved from 0.19985 to 0.21010, saving model to saved_models\weight-model-improvement-13-0.21-20211124-140751.h5
# 314/314 [==============================] - 80s 254ms/step - loss: 2.9502 - accuracy: 0.2088 - val_loss: 2.9615 - val_accuracy: 0.2101 - lr: 0.0010
# Epoch 14/100
# 314/314 [==============================] - ETA: 0s - loss: 2.8394 - accuracy: 0.2298 ETA: 2s - los
# Epoch 00014: val_accuracy did not improve from 0.21010
# 314/314 [==============================] - 78s 247ms/step - loss: 2.8394 - accuracy: 0.2298 - val_loss: 3.0827 - val_accuracy: 0.2094 - lr: 0.0010
# Epoch 15/100
# 314/314 [==============================] - ETA: 0s - loss: 2.8374 - accuracy: 0.2317
# Epoch 00015: val_accuracy improved from 0.21010 to 0.23646, saving model to saved_models\weight-model-improvement-15-0.24-20211124-140751.h5
# 314/314 [==============================] - 80s 254ms/step - loss: 2.8374 - accuracy: 0.2317 - val_loss: 2.8226 - val_accuracy: 0.2365 - lr: 0.0010
# Epoch 16/100
# 314/314 [==============================] - ETA: 0s - loss: 2.7788 - accuracy: 0.2494
# Epoch 00016: val_accuracy did not improve from 0.23646
# 314/314 [==============================] - 78s 248ms/step - loss: 2.7788 - accuracy: 0.2494 - val_loss: 3.3780 - val_accuracy: 0.1911 - lr: 0.0010
# Epoch 17/100
# 314/314 [==============================] - ETA: 0s - loss: 2.7493 - accuracy: 0.2500
# Epoch 00017: val_accuracy did not improve from 0.23646
# 314/314 [==============================] - 78s 249ms/step - loss: 2.7493 - accuracy: 0.2500 - val_loss: 3.7174 - val_accuracy: 0.1772 - lr: 0.0010
# Epoch 18/100
# 314/314 [==============================] - ETA: 0s - loss: 2.6542 - accuracy: 0.2732
# Epoch 00018: val_accuracy improved from 0.23646 to 0.24963, saving model to saved_models\weight-model-improvement-18-0.25-20211124-140751.h5
# 314/314 [==============================] - 81s 256ms/step - loss: 2.6542 - accuracy: 0.2732 - val_loss: 2.9534 - val_accuracy: 0.2496 - lr: 0.0010
# Epoch 19/100
# 314/314 [==============================] - ETA: 0s - loss: 2.6217 - accuracy: 0.2761
# Epoch 00019: val_accuracy improved from 0.24963 to 0.26428, saving model to saved_models\weight-model-improvement-19-0.26-20211124-140751.h5
# 314/314 [==============================] - 80s 256ms/step - loss: 2.6217 - accuracy: 0.2761 - val_loss: 2.8371 - val_accuracy: 0.2643 - lr: 0.0010
# Epoch 20/100
# 314/314 [==============================] - ETA: 0s - loss: 2.5588 - accuracy: 0.3012
# Epoch 00020: val_accuracy did not improve from 0.26428
# 314/314 [==============================] - 78s 248ms/step - loss: 2.5588 - accuracy: 0.3012 - val_loss: 2.8556 - val_accuracy: 0.2606 - lr: 0.0010
# Epoch 21/100
# 314/314 [==============================] - ETA: 0s - loss: 2.5174 - accuracy: 0.3017
# Epoch 00021: val_accuracy improved from 0.26428 to 0.27672, saving model to saved_models\weight-model-improvement-21-0.28-20211124-140751.h5
# 314/314 [==============================] - 80s 256ms/step - loss: 2.5174 - accuracy: 0.3017 - val_loss: 2.7249 - val_accuracy: 0.2767 - lr: 0.0010
# Epoch 22/100
# 314/314 [==============================] - ETA: 0s - loss: 2.4307 - accuracy: 0.3187
# Epoch 00022: val_accuracy improved from 0.27672 to 0.31186, saving model to saved_models\weight-model-improvement-22-0.31-20211124-140751.h5
# 314/314 [==============================] - 80s 255ms/step - loss: 2.4307 - accuracy: 0.3187 - val_loss: 2.6608 - val_accuracy: 0.3119 - lr: 0.0010
# Epoch 23/100
# 314/314 [==============================] - ETA: 0s - loss: 2.4004 - accuracy: 0.3301
# Epoch 00023: val_accuracy did not improve from 0.31186
# 314/314 [==============================] - 78s 246ms/step - loss: 2.4004 - accuracy: 0.3301 - val_loss: 2.7806 - val_accuracy: 0.3097 - lr: 0.0010
# Epoch 24/100
# 314/314 [==============================] - ETA: 0s - loss: 2.3847 - accuracy: 0.3278
# Epoch 00024: val_accuracy did not improve from 0.31186
# 314/314 [==============================] - 78s 247ms/step - loss: 2.3847 - accuracy: 0.3278 - val_loss: 2.8551 - val_accuracy: 0.2679 - lr: 0.0010
# Epoch 25/100
# 314/314 [==============================] - ETA: 0s - loss: 2.3333 - accuracy: 0.34 - ETA: 0s - loss: 2.3327 - accuracy: 0.3482
# Epoch 00025: val_accuracy improved from 0.31186 to 0.32650, saving model to saved_models\weight-model-improvement-25-0.33-20211124-140751.h5
# 314/314 [==============================] - 80s 253ms/step - loss: 2.3327 - accuracy: 0.3482 - val_loss: 2.6573 - val_accuracy: 0.3265 - lr: 0.0010
# Epoch 26/100
# 314/314 [==============================] - ETA: 0s - loss: 2.2727 - accuracy: 0.3659
# Epoch 00026: val_accuracy did not improve from 0.32650
# 314/314 [==============================] - 78s 247ms/step - loss: 2.2727 - accuracy: 0.3659 - val_loss: 2.6689 - val_accuracy: 0.3214 - lr: 0.0010
# Epoch 27/100
# 314/314 [==============================] - ETA: 0s - loss: 2.2620 - accuracy: 0.3650
# Epoch 00027: val_accuracy did not improve from 0.32650
# 314/314 [==============================] - 78s 250ms/step - loss: 2.2620 - accuracy: 0.3650 - val_loss: 2.6506 - val_accuracy: 0.3236 - lr: 0.0010
# Epoch 28/100
# 314/314 [==============================] - ETA: 0s - loss: 2.2040 - accuracy: 0.3769
# Epoch 00028: val_accuracy improved from 0.32650 to 0.34553, saving model to saved_models\weight-model-improvement-28-0.35-20211124-140751.h5
# 314/314 [==============================] - 80s 256ms/step - loss: 2.2040 - accuracy: 0.3769 - val_loss: 2.4432 - val_accuracy: 0.3455 - lr: 0.0010
# Epoch 29/100
# 314/314 [==============================] - ETA: 0s - loss: 2.1369 - accuracy: 0.4050
# Epoch 00029: val_accuracy improved from 0.34553 to 0.36237, saving model to saved_models\weight-model-improvement-29-0.36-20211124-140751.h5
# 314/314 [==============================] - 79s 251ms/step - loss: 2.1369 - accuracy: 0.4050 - val_loss: 2.4433 - val_accuracy: 0.3624 - lr: 0.0010
# Epoch 30/100
# 314/314 [==============================] - ETA: 0s - loss: 2.1346 - accuracy: 0.3960
# Epoch 00030: val_accuracy did not improve from 0.36237
# 314/314 [==============================] - 78s 247ms/step - loss: 2.1346 - accuracy: 0.3960 - val_loss: 23.2363 - val_accuracy: 0.0293 - lr: 0.0010
# Epoch 31/100
# 314/314 [==============================] - ETA: 0s - loss: 2.1124 - accuracy: 0.3997
# Epoch 00031: val_accuracy did not improve from 0.36237
# 314/314 [==============================] - 79s 252ms/step - loss: 2.1124 - accuracy: 0.3997 - val_loss: 2.8573 - val_accuracy: 0.2987 - lr: 0.0010
# Epoch 32/100
# 314/314 [==============================] - ETA: 0s - loss: 2.1093 - accuracy: 0.40 - ETA: 0s - loss: 2.1069 - accuracy: 0.4097
# Epoch 00032: val_accuracy improved from 0.36237 to 0.41801, saving model to saved_models\weight-model-improvement-32-0.42-20211124-140751.h5
# 314/314 [==============================] - 80s 255ms/step - loss: 2.1069 - accuracy: 0.4097 - val_loss: 2.2630 - val_accuracy: 0.4180 - lr: 0.0010
# Epoch 33/100
# 314/314 [==============================] - ETA: 0s - loss: 2.0784 - accuracy: 0.4171
# Epoch 00033: val_accuracy did not improve from 0.41801
# 314/314 [==============================] - 78s 247ms/step - loss: 2.0784 - accuracy: 0.4171 - val_loss: 2.3211 - val_accuracy: 0.3990 - lr: 0.0010
# Epoch 34/100
# 314/314 [==============================] - ETA: 0s - loss: 1.9985 - accuracy: 0.4264
# Epoch 00034: val_accuracy did not improve from 0.41801
# 314/314 [==============================] - 78s 246ms/step - loss: 1.9985 - accuracy: 0.4264 - val_loss: 2.4575 - val_accuracy: 0.3675 - lr: 0.0010
# Epoch 35/100
# 314/314 [==============================] - ETA: 0s - loss: 1.9810 - accuracy: 0.4358
# Epoch 00035: val_accuracy did not improve from 0.41801
# 314/314 [==============================] - 78s 247ms/step - loss: 1.9810 - accuracy: 0.4358 - val_loss: 2.2844 - val_accuracy: 0.4019 - lr: 0.0010
# Epoch 36/100
# 314/314 [==============================] - ETA: 0s - loss: 1.9363 - accuracy: 0.4435
# Epoch 00036: val_accuracy did not improve from 0.41801
# 314/314 [==============================] - 78s 247ms/step - loss: 1.9363 - accuracy: 0.4435 - val_loss: 2.3820 - val_accuracy: 0.3755 - lr: 0.0010
# Epoch 37/100
# 314/314 [==============================] - ETA: 0s - loss: 1.9359 - accuracy: 0.4558
# Epoch 00037: val_accuracy improved from 0.41801 to 0.42094, saving model to saved_models\weight-model-improvement-37-0.42-20211124-140751.h5
# 314/314 [==============================] - 80s 253ms/step - loss: 1.9359 - accuracy: 0.4558 - val_loss: 2.2246 - val_accuracy: 0.4209 - lr: 0.0010
# Epoch 38/100
# 314/314 [==============================] - ETA: 0s - loss: 1.9178 - accuracy: 0.4520
# Epoch 00038: val_accuracy did not improve from 0.42094
# 314/314 [==============================] - 78s 247ms/step - loss: 1.9178 - accuracy: 0.4520 - val_loss: 2.2517 - val_accuracy: 0.4187 - lr: 0.0010
# Epoch 39/100
# 314/314 [==============================] - ETA: 0s - loss: 1.8396 - accuracy: 0.4649
# Epoch 00039: val_accuracy did not improve from 0.42094
# 314/314 [==============================] - 78s 247ms/step - loss: 1.8396 - accuracy: 0.4649 - val_loss: 2.3266 - val_accuracy: 0.4056 - lr: 0.0010
# Epoch 40/100
# 314/314 [==============================] - ETA: 0s - loss: 1.8189 - accuracy: 0.4807
# Epoch 00040: val_accuracy did not improve from 0.42094
# 314/314 [==============================] - 77s 246ms/step - loss: 1.8189 - accuracy: 0.4807 - val_loss: 2.5330 - val_accuracy: 0.3712 - lr: 0.0010
# Epoch 41/100
# 314/314 [==============================] - ETA: 0s - loss: 1.8020 - accuracy: 0.4851
# Epoch 00041: val_accuracy improved from 0.42094 to 0.42826, saving model to saved_models\weight-model-improvement-41-0.43-20211124-140751.h5
# 314/314 [==============================] - 80s 253ms/step - loss: 1.8020 - accuracy: 0.4851 - val_loss: 2.1877 - val_accuracy: 0.4283 - lr: 0.0010
# Epoch 42/100
# 314/314 [==============================] - ETA: 0s - loss: 1.8072 - accuracy: 0.4830
# Epoch 00042: val_accuracy did not improve from 0.42826
# 314/314 [==============================] - 78s 247ms/step - loss: 1.8072 - accuracy: 0.4830 - val_loss: 2.3674 - val_accuracy: 0.4085 - lr: 0.0010
# Epoch 43/100
# 314/314 [==============================] - ETA: 0s - loss: 1.7648 - accuracy: 0.4917
# Epoch 00043: val_accuracy did not improve from 0.42826
# 314/314 [==============================] - 78s 247ms/step - loss: 1.7648 - accuracy: 0.4917 - val_loss: 2.2917 - val_accuracy: 0.4195 - lr: 0.0010
# Epoch 44/100
# 314/314 [==============================] - ETA: 0s - loss: 1.7170 - accuracy: 0.5134
# Epoch 00044: val_accuracy did not improve from 0.42826
# 314/314 [==============================] - 78s 247ms/step - loss: 1.7170 - accuracy: 0.5134 - val_loss: 2.3185 - val_accuracy: 0.4085 - lr: 0.0010
# Epoch 45/100
# 314/314 [==============================] - ETA: 0s - loss: 1.7322 - accuracy: 0.5098
# Epoch 00045: val_accuracy improved from 0.42826 to 0.43411, saving model to saved_models\weight-model-improvement-45-0.43-20211124-140751.h5
# 314/314 [==============================] - 80s 254ms/step - loss: 1.7322 - accuracy: 0.5098 - val_loss: 2.3203 - val_accuracy: 0.4341 - lr: 0.0010
# Epoch 46/100
# 314/314 [==============================] - ETA: 0s - loss: 1.6755 - accuracy: 0.5136
# Epoch 00046: val_accuracy did not improve from 0.43411
# 314/314 [==============================] - 78s 247ms/step - loss: 1.6755 - accuracy: 0.5136 - val_loss: 2.4967 - val_accuracy: 0.4019 - lr: 0.0010
# Epoch 47/100
# 314/314 [==============================] - ETA: 0s - loss: 1.6693 - accuracy: 0.5055
# Epoch 00047: val_accuracy did not improve from 0.43411
# 314/314 [==============================] - 78s 247ms/step - loss: 1.6693 - accuracy: 0.5055 - val_loss: 2.3350 - val_accuracy: 0.4231 - lr: 0.0010
# Epoch 48/100
# 314/314 [==============================] - ETA: 0s - loss: 1.6324 - accuracy: 0.5232
# Epoch 00048: val_accuracy improved from 0.43411 to 0.47218, saving model to saved_models\weight-model-improvement-48-0.47-20211124-140751.h5
# 314/314 [==============================] - 80s 253ms/step - loss: 1.6324 - accuracy: 0.5232 - val_loss: 2.0912 - val_accuracy: 0.4722 - lr: 0.0010
# Epoch 49/100
# 314/314 [==============================] - ETA: 0s - loss: 1.6342 - accuracy: 0.5283
# Epoch 00049: val_accuracy did not improve from 0.47218
# 314/314 [==============================] - 78s 247ms/step - loss: 1.6342 - accuracy: 0.5283 - val_loss: 2.0590 - val_accuracy: 0.4671 - lr: 0.0010
# Epoch 50/100
# 314/314 [==============================] - ETA: 0s - loss: 1.6300 - accuracy: 0.5249
# Epoch 00050: val_accuracy did not improve from 0.47218
# 314/314 [==============================] - 78s 247ms/step - loss: 1.6300 - accuracy: 0.5249 - val_loss: 2.2138 - val_accuracy: 0.4590 - lr: 0.0010
# Epoch 51/100
# 314/314 [==============================] - ETA: 0s - loss: 1.5569 - accuracy: 0.5514
# Epoch 00051: val_accuracy did not improve from 0.47218
# 314/314 [==============================] - 77s 246ms/step - loss: 1.5569 - accuracy: 0.5514 - val_loss: 2.3275 - val_accuracy: 0.4348 - lr: 0.0010
# Epoch 52/100
# 314/314 [==============================] - ETA: 0s - loss: 1.5561 - accuracy: 0.5410
# Epoch 00052: val_accuracy did not improve from 0.47218
# 314/314 [==============================] - 78s 247ms/step - loss: 1.5561 - accuracy: 0.5410 - val_loss: 2.1085 - val_accuracy: 0.4700 - lr: 0.0010
# Epoch 53/100
# 314/314 [==============================] - ETA: 0s - loss: 1.5303 - accuracy: 0.5489
# Epoch 00053: val_accuracy did not improve from 0.47218
# 314/314 [==============================] - 77s 246ms/step - loss: 1.5303 - accuracy: 0.5489 - val_loss: 2.2106 - val_accuracy: 0.4619 - lr: 0.0010
# Epoch 54/100
# 314/314 [==============================] - ETA: 0s - loss: 1.5227 - accuracy: 0.5534
# Epoch 00054: val_accuracy did not improve from 0.47218
# 314/314 [==============================] - 77s 246ms/step - loss: 1.5227 - accuracy: 0.5534 - val_loss: 2.0679 - val_accuracy: 0.4714 - lr: 0.0010
# Epoch 55/100
# 314/314 [==============================] - ETA: 0s - loss: 1.4960 - accuracy: 0.5655
# Epoch 00055: val_accuracy did not improve from 0.47218
# 314/314 [==============================] - 77s 246ms/step - loss: 1.4960 - accuracy: 0.5655 - val_loss: 2.0745 - val_accuracy: 0.4707 - lr: 0.0010
# Epoch 56/100
# 314/314 [==============================] - ETA: 0s - loss: 1.4668 - accuracy: 0.5778
# Epoch 00056: val_accuracy did not improve from 0.47218
# 314/314 [==============================] - 78s 247ms/step - loss: 1.4668 - accuracy: 0.5778 - val_loss: 2.2531 - val_accuracy: 0.4671 - lr: 0.0010
# Epoch 57/100
# 314/314 [==============================] - ETA: 0s - loss: 1.4456 - accuracy: 0.5784
# Epoch 00057: val_accuracy did not improve from 0.47218
# 314/314 [==============================] - 78s 247ms/step - loss: 1.4456 - accuracy: 0.5784 - val_loss: 2.4420 - val_accuracy: 0.4480 - lr: 0.0010
# Epoch 58/100
# 314/314 [==============================] - ETA: 0s - loss: 1.4103 - accuracy: 0.5833
# Epoch 00058: val_accuracy did not improve from 0.47218
# 314/314 [==============================] - 77s 246ms/step - loss: 1.4103 - accuracy: 0.5833 - val_loss: 2.3405 - val_accuracy: 0.4663 - lr: 0.0010
# Epoch 59/100
# 314/314 [==============================] - ETA: 0s - loss: 1.4122 - accuracy: 0.5848
# Epoch 00059: val_accuracy did not improve from 0.47218
# 314/314 [==============================] - 78s 248ms/step - loss: 1.4122 - accuracy: 0.5848 - val_loss: 2.3728 - val_accuracy: 0.4539 - lr: 0.0010
# Epoch 60/100
# 314/314 [==============================] - ETA: 0s - loss: 1.1730 - accuracy: 0.65 - ETA: 0s - loss: 1.1733 - accuracy: 0.6548
# Epoch 00060: val_accuracy improved from 0.47218 to 0.52269, saving model to saved_models\weight-model-improvement-60-0.52-20211124-140751.h5
# 314/314 [==============================] - 80s 255ms/step - loss: 1.1733 - accuracy: 0.6548 - val_loss: 2.0298 - val_accuracy: 0.5227 - lr: 1.0000e-04
# Epoch 61/100
# 314/314 [==============================] - ETA: 0s - loss: 1.0859 - accuracy: 0.6669
# Epoch 00061: val_accuracy improved from 0.52269 to 0.53587, saving model to saved_models\weight-model-improvement-61-0.54-20211124-140751.h5
# 314/314 [==============================] - 81s 257ms/step - loss: 1.0859 - accuracy: 0.6669 - val_loss: 1.9591 - val_accuracy: 0.5359 - lr: 1.0000e-04
# Epoch 62/100
# 314/314 [==============================] - ETA: 0s - loss: 1.0963 - accuracy: 0.6667
# Epoch 00062: val_accuracy improved from 0.53587 to 0.54392, saving model to saved_models\weight-model-improvement-62-0.54-20211124-140751.h5
# 314/314 [==============================] - 80s 255ms/step - loss: 1.0963 - accuracy: 0.6667 - val_loss: 1.9485 - val_accuracy: 0.5439 - lr: 1.0000e-04
# Epoch 63/100
# 314/314 [==============================] - ETA: 0s - loss: 1.0747 - accuracy: 0.6862
# Epoch 00063: val_accuracy improved from 0.54392 to 0.55344, saving model to saved_models\weight-model-improvement-63-0.55-20211124-140751.h5
# 314/314 [==============================] - 80s 255ms/step - loss: 1.0747 - accuracy: 0.6862 - val_loss: 1.9060 - val_accuracy: 0.5534 - lr: 1.0000e-04
# Epoch 64/100
# 314/314 [==============================] - ETA: 0s - loss: 1.0396 - accuracy: 0.6871
# Epoch 00064: val_accuracy improved from 0.55344 to 0.55637, saving model to saved_models\weight-model-improvement-64-0.56-20211124-140751.h5
# 314/314 [==============================] - 80s 255ms/step - loss: 1.0396 - accuracy: 0.6871 - val_loss: 1.9093 - val_accuracy: 0.5564 - lr: 1.0000e-04
# Epoch 65/100
# 314/314 [==============================] - ETA: 0s - loss: 1.0299 - accuracy: 0.6841
# Epoch 00065: val_accuracy did not improve from 0.55637
# 314/314 [==============================] - 79s 250ms/step - loss: 1.0299 - accuracy: 0.6841 - val_loss: 2.0020 - val_accuracy: 0.5366 - lr: 1.0000e-04
# Epoch 66/100
# 314/314 [==============================] - ETA: 0s - loss: 1.0261 - accuracy: 0.6830
# Epoch 00066: val_accuracy improved from 0.55637 to 0.55783, saving model to saved_models\weight-model-improvement-66-0.56-20211124-140751.h5
# 314/314 [==============================] - 80s 255ms/step - loss: 1.0261 - accuracy: 0.6830 - val_loss: 1.9424 - val_accuracy: 0.5578 - lr: 1.0000e-04
# Epoch 67/100
# 314/314 [==============================] - ETA: 0s - loss: 0.9907 - accuracy: 0.6986
# Epoch 00067: val_accuracy did not improve from 0.55783
# 314/314 [==============================] - 78s 248ms/step - loss: 0.9907 - accuracy: 0.6986 - val_loss: 1.9737 - val_accuracy: 0.5498 - lr: 1.0000e-04
# Epoch 68/100
# 314/314 [==============================] - ETA: 0s - loss: 0.9865 - accuracy: 0.6992
# Epoch 00068: val_accuracy improved from 0.55783 to 0.56662, saving model to saved_models\weight-model-improvement-68-0.57-20211124-140751.h5
# 314/314 [==============================] - 80s 255ms/step - loss: 0.9865 - accuracy: 0.6992 - val_loss: 1.9451 - val_accuracy: 0.5666 - lr: 1.0000e-04
# Epoch 69/100
# 314/314 [==============================] - ETA: 0s - loss: 0.9745 - accuracy: 0.7047
# Epoch 00069: val_accuracy did not improve from 0.56662
# 314/314 [==============================] - 78s 248ms/step - loss: 0.9745 - accuracy: 0.7047 - val_loss: 1.9973 - val_accuracy: 0.5512 - lr: 1.0000e-04
# Epoch 70/100
# 314/314 [==============================] - ETA: 0s - loss: 0.9466 - accuracy: 0.7113
# Epoch 00070: val_accuracy did not improve from 0.56662
# 314/314 [==============================] - 77s 246ms/step - loss: 0.9466 - accuracy: 0.7113 - val_loss: 2.0379 - val_accuracy: 0.5476 - lr: 1.0000e-04
# Epoch 71/100
# 314/314 [==============================] - ETA: 0s - loss: 0.9745 - accuracy: 0.7026
# Epoch 00071: val_accuracy did not improve from 0.56662
# 314/314 [==============================] - 77s 246ms/step - loss: 0.9745 - accuracy: 0.7026 - val_loss: 1.9299 - val_accuracy: 0.5600 - lr: 1.0000e-04
# Epoch 72/100
# 314/314 [==============================] - ETA: 0s - loss: 0.9817 - accuracy: 0.7003
# Epoch 00072: val_accuracy did not improve from 0.56662
# 314/314 [==============================] - 77s 246ms/step - loss: 0.9817 - accuracy: 0.7003 - val_loss: 1.9090 - val_accuracy: 0.5600 - lr: 1.0000e-04
# Epoch 73/100
# 314/314 [==============================] - ETA: 0s - loss: 0.9417 - accuracy: 0.7160
# Epoch 00073: val_accuracy improved from 0.56662 to 0.56955, saving model to saved_models\weight-model-improvement-73-0.57-20211124-140751.h5
# 314/314 [==============================] - 80s 254ms/step - loss: 0.9417 - accuracy: 0.7160 - val_loss: 1.9876 - val_accuracy: 0.5695 - lr: 1.0000e-04
# Epoch 74/100
# 314/314 [==============================] - ETA: 0s - loss: 0.9342 - accuracy: 0.7100 ETA: 3s - loss: 0.9361 - accuracy - ETA: 2s - loss:
# Epoch 00074: val_accuracy did not improve from 0.56955
# 314/314 [==============================] - 78s 249ms/step - loss: 0.9342 - accuracy: 0.7100 - val_loss: 1.9426 - val_accuracy: 0.5637 - lr: 1.0000e-05
# Epoch 75/100
# 314/314 [==============================] - ETA: 0s - loss: 0.9161 - accuracy: 0.7236
# Epoch 00075: val_accuracy did not improve from 0.56955
# 314/314 [==============================] - 78s 248ms/step - loss: 0.9161 - accuracy: 0.7236 - val_loss: 1.9351 - val_accuracy: 0.5608 - lr: 1.0000e-05
# Epoch 76/100
# 314/314 [==============================] - ETA: 0s - loss: 0.9248 - accuracy: 0.7198 ETA: 1s - loss: 0.9233
# Epoch 00076: val_accuracy did not improve from 0.56955
# 314/314 [==============================] - 79s 251ms/step - loss: 0.9248 - accuracy: 0.7198 - val_loss: 1.9830 - val_accuracy: 0.5542 - lr: 1.0000e-05
# Epoch 77/100
# 314/314 [==============================] - ETA: 0s - loss: 0.8978 - accuracy: 0.71 - ETA: 0s - loss: 0.8987 - accuracy: 0.7190
# Epoch 00077: val_accuracy did not improve from 0.56955
# 314/314 [==============================] - 78s 249ms/step - loss: 0.8987 - accuracy: 0.7190 - val_loss: 1.9287 - val_accuracy: 0.5615 - lr: 1.0000e-05
# Epoch 78/100
# 314/314 [==============================] - ETA: 0s - loss: 0.9181 - accuracy: 0.7194
# Epoch 00078: val_accuracy improved from 0.56955 to 0.57101, saving model to saved_models\weight-model-improvement-78-0.57-20211124-140751.h5
# Restoring model weights from the end of the best epoch: 63.
# 314/314 [==============================] - 80s 255ms/step - loss: 0.9181 - accuracy: 0.7194 - val_loss: 1.9558 - val_accuracy: 0.5710 - lr: 1.0000e-05
# Epoch 00078: early stopping

# %%
reduction_loss_history[["accuracy","val_accuracy"]].plot()
# Out:
# <AxesSubplot:>
